# %%
import numpy as np

def series_sum(trunc=1000):
    total = 0.0
    for k in range(1, trunc+1):
        denom = np.sinh(np.pi * k * np.sqrt(3) / 2)
        total += k**2 / denom**2
    return total

series_value = series_sum(1000)
result = (np.pi**2 / 18) * series_value
print(result)
# Out:
# 0.009753533759229095
# <ipython-input-15-180e5674895b>:7: RuntimeWarning: overflow encountered in scalar power
#   total += k**2 / denom**2
# <ipython-input-15-180e5674895b>:6: RuntimeWarning: overflow encountered in sinh
#   denom = np.sinh(np.pi * k * np.sqrt(3) / 2)
