# %%
# ============================================================
# 0.  Imports
# ============================================================
import sympy as sp, itertools, math, time
from fractions import Fraction
from collections import defaultdict

# ============================================================
# 1.  Dimensional symbols to strip
# ============================================================
ℏ,c,G,k_B = sp.symbols('hbar c G k_B')
ε0,μ0,e,h = sp.symbols('epsilon_0 mu_0 e h')
STRIP = {ℏ,c,G,k_B,h,ε0,μ0}

# ============================================================
# 2.  Equation set  (π-rich)
# ============================================================
E,m,F,a,q1,q2,r,ν,T = sp.symbols('E m F a q1 q2 r nu T')
λ,ρ = sp.symbols('lambda rho')
σ_SB = sp.symbols('sigma_SB')
α   = sp.symbols('alpha')

EQU = {
    "Coulomb":   sp.Eq(F, 1/(4*sp.pi*ε0)*q1*q2/r**2),
    "α":         sp.Eq(α, e**2/(4*sp.pi*ε0*ℏ*c)),
    "SB":        sp.Eq(σ_SB, sp.pi**2*k_B**4/(60*ℏ**3*c**2)),
    "BB-u":      sp.Eq(sp.symbols('u'), 8*sp.pi**5*k_B**4/(15*h**3*c**3)),
    "RJ":        sp.Eq(sp.symbols('u_RJ'), 8*sp.pi*k_B*T/λ**4),
    "Casimir":   sp.Eq(sp.symbols('P_cas'), -sp.pi**2*ℏ*c/(240*a**4)),
    "Friedmann": sp.Eq(sp.symbols('H2'), 8*sp.pi*G*ρ/3),
    "ζ(3)":      sp.Eq(sp.symbols('z3'), sp.zeta(3)),
}

# ============================================================
# 3.  Strip units & gather coefficients (symbolic)
# ============================================================
def strip(expr):
    return sp.factor(expr.xreplace({u:1 for u in STRIP}))

coeffs=[]
for tag,eq in EQU.items():
    for side in (eq.lhs,eq.rhs):
        s=strip(side)
        for term in sp.Add.make_args(s.expand()):
            c,_=term.as_coeff_Mul()
            if c not in (1,-1):
                coeffs.append((c,tag))

# ============================================================
# 4.  Build constant set  (π^k, √2, √3, e, ζ(3), ln2, φ, γ)
# ============================================================
CATS=set()
for k in range(-6,7):
    CATS.add(sp.pi**k)
    CATS.add(-sp.pi**k)
CATS|={sp.E,-sp.E, sp.sqrt(2),-sp.sqrt(2),
       sp.sqrt(3),-sp.sqrt(3),
       sp.zeta(3),-sp.zeta(3),
       sp.log(2),-sp.log(2),
       (1+sp.sqrt(5))/2, -(1+sp.sqrt(5))/2,
       sp.EulerGamma, -sp.EulerGamma}

def contains_constant(expr):
    return any(expr.has(c) for c in CATS)

# ============================================================
# 5.  Ratio scan  (symbolic → numeric tolerance)
# ============================================================
TOL=1e-8
hits=defaultdict(list)

for (c1,e1),(c2,e2) in itertools.combinations(coeffs,2):
    ratio = sp.simplify(c1/c2)
    if contains_constant(ratio):
        hits[(e1,e2)].append(f"{c1}/{c2} = {sp.simplify(ratio)}")
        continue
    r_float=float(ratio.evalf())
    q=Fraction(r_float).limit_denominator(100)
    if abs(r_float-q)<TOL and max(abs(q.numerator),q.denominator)>1:
        hits[(e1,e2)].append(f"{c1}/{c2} ≈ {q.numerator}/{q.denominator}")

print("🔍  RATIO HITS (π-powers, e, ζ, √… or m/n≤100)\n"+"-"*70)
if not hits:
    print("  (none)")
else:
    for (a,b),lst in hits.items():
        for t in lst: print(f"{a:10s} vs {b:10s}: {t}")

# ============================================================
# 6.  brute PSLQ  (≤5 terms, |c|≤30, symbolic floats)
# ============================================================
def brute_pslq(vals, max_terms=5, max_coeff=30, tol=1e-12):
    n=len(vals)
    for k in range(2,min(max_terms,n)+1):
        for idx in itertools.combinations(range(n),k):
            subset=[vals[i] for i in idx]
            for vec in itertools.product(range(-max_coeff,max_coeff+1), repeat=k):
                if all(v==0 for v in vec): continue
                if math.gcd(*vec)!=1: continue
                if abs(sum(c*v for c,v in zip(vec,subset)))<tol:
                    rel=[0]*n
                    for i,c in zip(idx,vec): rel[i]=c
                    return rel
    return None

values=[float(c.evalf(50)) for c,_ in coeffs]
print("\n🔑  INTEGER RELATION SEARCH (≤5 terms, |c|≤30)…")
rel=brute_pslq(values)
if rel:
    expr=" + ".join(f"{c}·{coeffs[i][0]}" for i,c in enumerate(rel) if c)
    print("  Found:", expr,"= 0")
else:
    print("  No relation within limits.")
# Out:
# 🔍  RATIO HITS (π-powers, e, ζ, √… or m/n≤100)
# ----------------------------------------------------------------------
# Coulomb    vs α         : 1/4/1/4 = 1
# Coulomb    vs SB        : 1/4/1/60 ≈ 15/1
# Coulomb    vs BB-u      : 1/4/8/15 ≈ 15/32
# Coulomb    vs RJ        : 1/4/8 ≈ 1/32
# Coulomb    vs Casimir   : 1/4/-1/240 ≈ -60/1
# Coulomb    vs Friedmann : 1/4/8/3 ≈ 3/32
# α          vs SB        : 1/4/1/60 ≈ 15/1
# α          vs BB-u      : 1/4/8/15 ≈ 15/32
# α          vs RJ        : 1/4/8 ≈ 1/32
# α          vs Casimir   : 1/4/-1/240 ≈ -60/1
# α          vs Friedmann : 1/4/8/3 ≈ 3/32
# SB         vs BB-u      : 1/60/8/15 ≈ 1/32
# SB         vs Casimir   : 1/60/-1/240 ≈ -4/1
# BB-u       vs RJ        : 8/15/8 ≈ 1/15
# BB-u       vs Casimir   : 8/15/-1/240 ≈ -128/1
# BB-u       vs Friedmann : 8/15/8/3 ≈ 1/5
# RJ         vs Casimir   : 8/-1/240 ≈ -1920/1
# RJ         vs Friedmann : 8/8/3 ≈ 3/1
#
# 🔑  INTEGER RELATION SEARCH (≤5 terms, |c|≤30)…
#   Found: -1·1/4 + 1·1/4 = 0

# %%
import sys

# 1) Force-install Sympy 1.13.1 (the version Torch wants).
# !{sys.executable} -m pip install --quiet --force-reinstall "sympy==1.13.1"

# 2) Restart this Colab runtime so the new Sympy is in effect.
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)  # runtime restart
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 31.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# {'status': 'ok', 'restart': True}

# %%
# ============================================================
# 0.  Imports (nothing extra to install)
# ============================================================
import sympy as sp, itertools, math, time
from fractions import Fraction
from collections import defaultdict

# ============================================================
# 1.  Dimensional symbols to strip (π, e, ζ… stay!)
# ============================================================
ℏ, c, G, k_B, R = sp.symbols('hbar c G k_B R')
ε0, μ0, e, h    = sp.symbols('epsilon_0 mu_0 e h')
STRIP = {ℏ, c, G, k_B, R, h, ε0, μ0}

# ============================================================
# 2.  Declare general-purpose symbols once
# ============================================================
E,m,F,a,q1,q2,r,ν,T,P,V,n,λ,ρ,v = sp.symbols(
    'E m F a q1 q2 r nu T P V n lambda rho v')
α,β,γ = sp.symbols('alpha beta gamma')
Δ     = sp.symbols('Delta')
ζ3    = sp.symbols('zeta3')
φ     = sp.symbols('phi')
a0, R_inf = sp.symbols('a0 R_inf')
σ_SB  = sp.symbols('sigma_SB')
H0, Ω_m = sp.symbols('H0 Omega_m')
a_lat, ω_D = sp.symbols('a_lat omega_D')
μ      = sp.symbols('mu')   # viscosity for Stokes drag

# ============================================================
# 3.  Equation library  (~40 iconic formulas)
# ============================================================
EQU = {
    # Classical / atomic
    "Einstein mc²"      : sp.Eq(E, m*c**2),
    "Planck E=hν"       : sp.Eq(E, h*ν),
    "de Broglie"        : sp.Eq(λ, ℏ/(m*c)),
    "Fine α"            : sp.Eq(α, e**2/(4*sp.pi*ε0*ℏ*c)),
    "Coulomb"           : sp.Eq(F, 1/(4*sp.pi*ε0)*q1*q2/r**2),
    "Bohr radius"       : sp.Eq(a0, 4*sp.pi*ε0*ℏ**2/(m*e**2)),
    "Rydberg R∞"        : sp.Eq(R_inf, α**2*m*c/(2*h)),
    # Thermodynamics / stat mech
    "Equip 3/2 kT"      : sp.Eq(E, (3/2)*k_B*T),
    "Boltz kT"          : sp.Eq(E, k_B*T),
    "Stefan–Boltz"      : sp.Eq(σ_SB, sp.pi**2*k_B**4/(60*ℏ**3*c**2)),
    "BB energy u"       : sp.Eq(sp.symbols('u'), 8*sp.pi**5*k_B**4/(15*h**3*c**3)),
    "Rayleigh–Jeans"    : sp.Eq(sp.symbols('u_RJ'), 8*sp.pi*k_B*T/λ**4),
    # Quantum vacuum / QED
    "Casimir P"         : sp.Eq(sp.symbols('P_cas'), -sp.pi**2*ℏ*c/(240*a**4)),
    "Lamb 2s–2p"        : sp.Eq(sp.symbols('ΔE_L'), α**5*m*c**2/(6*sp.pi**2)),
    # Condensed matter
    "BCS gap"           : sp.Eq(Δ, 3.528*k_B*T),
    "Josephson K_J"     : sp.Eq(sp.symbols('K_J'), 2*e/h),
    "von Klitzing R_K"  : sp.Eq(sp.symbols('R_K'), h/e**2),
    "Stokes drag"       : sp.Eq(F, 6*sp.pi*μ*r*v),
    "Debye ω_D"         : sp.Eq(ω_D, (6*sp.pi**2*n/a_lat**3)**(1/3)),
    # Cosmology
    "Friedmann 8π/3"    : sp.Eq(sp.symbols('H2'), 8*sp.pi*G*ρ/3),
    "Critical density"  : sp.Eq(sp.symbols('ρ_c'), 3*H0**2/(8*sp.pi*G)),
    # Pure math constants
    "ζ(3)"              : sp.Eq(ζ3, sp.zeta(3)),
    "ζ(5)"              : sp.Eq(sp.symbols('z5'), sp.zeta(5)),
    "Catalan G"         : sp.Eq(sp.symbols('G_cat'), sp.Catalan),
    "Golden φ"          : sp.Eq(φ, (1+sp.sqrt(5))/2),
    "Euler γ"           : sp.Eq(sp.symbols('gamma_EM'), sp.EulerGamma),
}

# ============================================================
# 4.  Strip units & collect coefficients (symbolic)
# ============================================================
def strip(expr):
    return sp.factor(expr.xreplace({u:1 for u in STRIP}))

coeffs=[]
for tag,eq in EQU.items():
    for side in (eq.lhs, eq.rhs):
        for term in sp.Add.make_args(strip(side).expand()):
            coeff,_ = term.as_coeff_Mul()
            if coeff not in (1,-1):
                coeffs.append((coeff, tag))

# ============================================================
# 5.  “Interesting” = not a pure rational number
# ============================================================
def interesting(expr):
    return not expr.is_Rational

# ============================================================
# 6.  Ratio scan  (transcendentals or m/n≤100)
# ============================================================
TOL=1e-8
hits=defaultdict(list)
for (c1,e1),(c2,e2) in itertools.combinations(coeffs,2):
    ratio = sp.simplify(c1/c2)
    if interesting(ratio):
        hits[(e1,e2)].append(f"{c1}/{c2} = {ratio}")
        continue
    r=float(ratio)
    q=Fraction(r).limit_denominator(100)
    if abs(r-q)<TOL and max(abs(q.numerator),q.denominator)>1:
        hits[(e1,e2)].append(f"{c1}/{c2} ≈ {q.numerator}/{q.denominator}")

print("🔍  RATIO HITS (π-powers, ζ, √… or m/n≤100)\n"+"-"*70)
if hits:
    for (a,b),lst in hits.items():
        for t in lst:
            print(f"{a:18s} vs {b:18s}: {t}")
else:
    print("  (none)")

# ============================================================
# 7.  Pure-Python brute PSLQ (≤5 terms, |c|≤30)
# ============================================================
def gcd_list(nums):
    g=0
    for n in nums: g=math.gcd(g,int(n))
    return abs(g)

def brute_pslq(vals,max_terms=5,max_coeff=30,tol=1e-12):
    n=len(vals)
    for k in range(2,min(max_terms,n)+1):
        for idx in itertools.combinations(range(n),k):
            subset=[vals[i] for i in idx]
            for vec in itertools.product(range(-max_coeff,max_coeff+1), repeat=k):
                if all(v==0 for v in vec): continue
                if gcd_list(vec)!=1: continue
                if abs(sum(c*v for c,v in zip(vec,subset)))<tol:
                    rel=[0]*n
                    for i,c in zip(idx,vec): rel[i]=c
                    return rel
    return None

values=[float(c.evalf(50)) for c,_ in coeffs]
print("\n🔑  INTEGER RELATION SEARCH (≤5 terms, |c|≤30)…")
t0=time.time()
rel=brute_pslq(values)
if rel:
    expr=" + ".join(f"{c}·{coeffs[i][0]}" for i,c in enumerate(rel) if c)
    print("  Found:",expr,"= 0")
else:
    print("  No relation within limits.")
print(f"  (elapsed {time.time()-t0:.2f}s)")
# Out:
# 🔍  RATIO HITS (π-powers, ζ, √… or m/n≤100)
# ----------------------------------------------------------------------
# Fine α             vs Bohr radius       : 1/4/4 ≈ 1/16
# Fine α             vs Rydberg R∞        : 1/4/1/2 ≈ 1/2
# Fine α             vs Equip 3/2 kT      : 1/4/1.50000000000000 = 0.166666666666667
# Fine α             vs Stefan–Boltz      : 1/4/1/60 ≈ 15/1
# Fine α             vs BB energy u       : 1/4/8/15 ≈ 15/32
# Fine α             vs Rayleigh–Jeans    : 1/4/8 ≈ 1/32
# Fine α             vs Casimir P         : 1/4/-1/240 ≈ -60/1
# Fine α             vs Lamb 2s–2p        : 1/4/1/6 ≈ 3/2
# Fine α             vs BCS gap           : 1/4/3.52800000000000 = 0.0708616780045351
# Fine α             vs Josephson K_J     : 1/4/2 ≈ 1/8
# Fine α             vs Stokes drag       : 1/4/6 ≈ 1/24
# Fine α             vs Debye ω_D         : 1/4/1.81712059283214 = 0.137580302037276
# Fine α             vs Friedmann 8π/3    : 1/4/8/3 ≈ 3/32
# Fine α             vs Critical density  : 1/4/3/8 ≈ 2/3
# Fine α             vs Golden φ          : 1/4/1/2 ≈ 1/2
# Fine α             vs Golden φ          : 1/4/1/2 ≈ 1/2
# Coulomb            vs Bohr radius       : 1/4/4 ≈ 1/16
# Coulomb            vs Rydberg R∞        : 1/4/1/2 ≈ 1/2
# Coulomb            vs Equip 3/2 kT      : 1/4/1.50000000000000 = 0.166666666666667
# Coulomb            vs Stefan–Boltz      : 1/4/1/60 ≈ 15/1
# Coulomb            vs BB energy u       : 1/4/8/15 ≈ 15/32
# Coulomb            vs Rayleigh–Jeans    : 1/4/8 ≈ 1/32
# Coulomb            vs Casimir P         : 1/4/-1/240 ≈ -60/1
# Coulomb            vs Lamb 2s–2p        : 1/4/1/6 ≈ 3/2
# Coulomb            vs BCS gap           : 1/4/3.52800000000000 = 0.0708616780045351
# Coulomb            vs Josephson K_J     : 1/4/2 ≈ 1/8
# Coulomb            vs Stokes drag       : 1/4/6 ≈ 1/24
# Coulomb            vs Debye ω_D         : 1/4/1.81712059283214 = 0.137580302037276
# Coulomb            vs Friedmann 8π/3    : 1/4/8/3 ≈ 3/32
# Coulomb            vs Critical density  : 1/4/3/8 ≈ 2/3
# Coulomb            vs Golden φ          : 1/4/1/2 ≈ 1/2
# Coulomb            vs Golden φ          : 1/4/1/2 ≈ 1/2
# Bohr radius        vs Rydberg R∞        : 4/1/2 ≈ 8/1
# Bohr radius        vs Equip 3/2 kT      : 4/1.50000000000000 = 2.66666666666667
# Bohr radius        vs Stefan–Boltz      : 4/1/60 ≈ 240/1
# Bohr radius        vs BB energy u       : 4/8/15 ≈ 15/2
# Bohr radius        vs Rayleigh–Jeans    : 4/8 ≈ 1/2
# Bohr radius        vs Casimir P         : 4/-1/240 ≈ -960/1
# Bohr radius        vs Lamb 2s–2p        : 4/1/6 ≈ 24/1
# Bohr radius        vs BCS gap           : 4/3.52800000000000 = 1.13378684807256
# Bohr radius        vs Josephson K_J     : 4/2 ≈ 2/1
# Bohr radius        vs Stokes drag       : 4/6 ≈ 2/3
# Bohr radius        vs Debye ω_D         : 4/1.81712059283214 = 2.20128483259642
# Bohr radius        vs Friedmann 8π/3    : 4/8/3 ≈ 3/2
# Bohr radius        vs Critical density  : 4/3/8 ≈ 32/3
# Bohr radius        vs Golden φ          : 4/1/2 ≈ 8/1
# Bohr radius        vs Golden φ          : 4/1/2 ≈ 8/1
# Rydberg R∞         vs Equip 3/2 kT      : 1/2/1.50000000000000 = 0.333333333333333
# Rydberg R∞         vs Stefan–Boltz      : 1/2/1/60 ≈ 30/1
# Rydberg R∞         vs BB energy u       : 1/2/8/15 ≈ 15/16
# Rydberg R∞         vs Rayleigh–Jeans    : 1/2/8 ≈ 1/16
# Rydberg R∞         vs Casimir P         : 1/2/-1/240 ≈ -120/1
# Rydberg R∞         vs Lamb 2s–2p        : 1/2/1/6 ≈ 3/1
# Rydberg R∞         vs BCS gap           : 1/2/3.52800000000000 = 0.141723356009070
# Rydberg R∞         vs Josephson K_J     : 1/2/2 ≈ 1/4
# Rydberg R∞         vs Stokes drag       : 1/2/6 ≈ 1/12
# Rydberg R∞         vs Debye ω_D         : 1/2/1.81712059283214 = 0.275160604074552
# Rydberg R∞         vs Friedmann 8π/3    : 1/2/8/3 ≈ 3/16
# Rydberg R∞         vs Critical density  : 1/2/3/8 ≈ 4/3
# Equip 3/2 kT       vs Stefan–Boltz      : 1.50000000000000/1/60 = 90.0000000000000
# Equip 3/2 kT       vs BB energy u       : 1.50000000000000/8/15 = 2.81250000000000
# Equip 3/2 kT       vs Rayleigh–Jeans    : 1.50000000000000/8 = 0.187500000000000
# Equip 3/2 kT       vs Casimir P         : 1.50000000000000/-1/240 = -360.000000000000
# Equip 3/2 kT       vs Lamb 2s–2p        : 1.50000000000000/1/6 = 9.00000000000000
# Equip 3/2 kT       vs BCS gap           : 1.50000000000000/3.52800000000000 = 0.425170068027211
# Equip 3/2 kT       vs Josephson K_J     : 1.50000000000000/2 = 0.750000000000000
# Equip 3/2 kT       vs Stokes drag       : 1.50000000000000/6 = 0.250000000000000
# Equip 3/2 kT       vs Debye ω_D         : 1.50000000000000/1.81712059283214 = 0.825481812223657
# Equip 3/2 kT       vs Friedmann 8π/3    : 1.50000000000000/8/3 = 0.562500000000000
# Equip 3/2 kT       vs Critical density  : 1.50000000000000/3/8 = 4.00000000000000
# Equip 3/2 kT       vs Golden φ          : 1.50000000000000/1/2 = 3.00000000000000
# Equip 3/2 kT       vs Golden φ          : 1.50000000000000/1/2 = 3.00000000000000
# Stefan–Boltz       vs BB energy u       : 1/60/8/15 ≈ 1/32
# Stefan–Boltz       vs Casimir P         : 1/60/-1/240 ≈ -4/1
# Stefan–Boltz       vs Lamb 2s–2p        : 1/60/1/6 ≈ 1/10
# Stefan–Boltz       vs BCS gap           : 1/60/3.52800000000000 = 0.00472411186696901
# Stefan–Boltz       vs Debye ω_D         : 1/60/1.81712059283214 = 0.00917202013581841
# Stefan–Boltz       vs Critical density  : 1/60/3/8 ≈ 2/45
# Stefan–Boltz       vs Golden φ          : 1/60/1/2 ≈ 1/30
# Stefan–Boltz       vs Golden φ          : 1/60/1/2 ≈ 1/30
# BB energy u        vs Rayleigh–Jeans    : 8/15/8 ≈ 1/15
# BB energy u        vs Casimir P         : 8/15/-1/240 ≈ -128/1
# BB energy u        vs Lamb 2s–2p        : 8/15/1/6 ≈ 16/5
# BB energy u        vs BCS gap           : 8/15/3.52800000000000 = 0.151171579743008
# BB energy u        vs Josephson K_J     : 8/15/2 ≈ 4/15
# BB energy u        vs Stokes drag       : 8/15/6 ≈ 4/45
# BB energy u        vs Debye ω_D         : 8/15/1.81712059283214 = 0.293504644346189
# BB energy u        vs Friedmann 8π/3    : 8/15/8/3 ≈ 1/5
# BB energy u        vs Critical density  : 8/15/3/8 ≈ 64/45
# BB energy u        vs Golden φ          : 8/15/1/2 ≈ 16/15
# BB energy u        vs Golden φ          : 8/15/1/2 ≈ 16/15
# Rayleigh–Jeans     vs Casimir P         : 8/-1/240 ≈ -1920/1
# Rayleigh–Jeans     vs Lamb 2s–2p        : 8/1/6 ≈ 48/1
# Rayleigh–Jeans     vs BCS gap           : 8/3.52800000000000 = 2.26757369614512
# Rayleigh–Jeans     vs Josephson K_J     : 8/2 ≈ 4/1
# Rayleigh–Jeans     vs Stokes drag       : 8/6 ≈ 4/3
# Rayleigh–Jeans     vs Debye ω_D         : 8/1.81712059283214 = 4.40256966519284
# Rayleigh–Jeans     vs Friedmann 8π/3    : 8/8/3 ≈ 3/1
# Rayleigh–Jeans     vs Critical density  : 8/3/8 ≈ 64/3
# Rayleigh–Jeans     vs Golden φ          : 8/1/2 ≈ 16/1
# Rayleigh–Jeans     vs Golden φ          : 8/1/2 ≈ 16/1
# Casimir P          vs Lamb 2s–2p        : -1/240/1/6 ≈ -1/40
# Casimir P          vs BCS gap           : -1/240/3.52800000000000 = -0.00118102796674225
# Casimir P          vs Debye ω_D         : -1/240/1.81712059283214 = -0.00229300503395460
# Casimir P          vs Critical density  : -1/240/3/8 ≈ -1/90
# Lamb 2s–2p         vs BCS gap           : 1/6/3.52800000000000 = 0.0472411186696901
# Lamb 2s–2p         vs Josephson K_J     : 1/6/2 ≈ 1/12
# Lamb 2s–2p         vs Stokes drag       : 1/6/6 ≈ 1/36
# Lamb 2s–2p         vs Debye ω_D         : 1/6/1.81712059283214 = 0.0917202013581841
# Lamb 2s–2p         vs Friedmann 8π/3    : 1/6/8/3 ≈ 1/16
# Lamb 2s–2p         vs Critical density  : 1/6/3/8 ≈ 4/9
# Lamb 2s–2p         vs Golden φ          : 1/6/1/2 ≈ 1/3
# Lamb 2s–2p         vs Golden φ          : 1/6/1/2 ≈ 1/3
# BCS gap            vs Josephson K_J     : 3.52800000000000/2 = 1.76400000000000
# BCS gap            vs Stokes drag       : 3.52800000000000/6 = 0.588000000000000
# BCS gap            vs Debye ω_D         : 3.52800000000000/1.81712059283214 = 1.94153322235004
# BCS gap            vs Friedmann 8π/3    : 3.52800000000000/8/3 = 1.32300000000000
# BCS gap            vs Critical density  : 3.52800000000000/3/8 = 9.40800000000000
# BCS gap            vs Golden φ          : 3.52800000000000/1/2 = 7.05600000000000
# BCS gap            vs Golden φ          : 3.52800000000000/1/2 = 7.05600000000000
# Josephson K_J      vs Stokes drag       : 2/6 ≈ 1/3
# Josephson K_J      vs Debye ω_D         : 2/1.81712059283214 = 1.10064241629821
# Josephson K_J      vs Friedmann 8π/3    : 2/8/3 ≈ 3/4
# Josephson K_J      vs Critical density  : 2/3/8 ≈ 16/3
# Josephson K_J      vs Golden φ          : 2/1/2 ≈ 4/1
# Josephson K_J      vs Golden φ          : 2/1/2 ≈ 4/1
# Stokes drag        vs Debye ω_D         : 6/1.81712059283214 = 3.30192724889463
# Stokes drag        vs Friedmann 8π/3    : 6/8/3 ≈ 9/4
# Stokes drag        vs Critical density  : 6/3/8 ≈ 16/1
# Stokes drag        vs Golden φ          : 6/1/2 ≈ 12/1
# Stokes drag        vs Golden φ          : 6/1/2 ≈ 12/1
# Debye ω_D          vs Friedmann 8π/3    : 1.81712059283214/8/3 = 0.681420222312052
# Debye ω_D          vs Critical density  : 1.81712059283214/3/8 = 4.84565491421904
# Debye ω_D          vs Golden φ          : 1.81712059283214/1/2 = 3.63424118566428
# Debye ω_D          vs Golden φ          : 1.81712059283214/1/2 = 3.63424118566428
# Friedmann 8π/3     vs Critical density  : 8/3/3/8 ≈ 64/9
# Friedmann 8π/3     vs Golden φ          : 8/3/1/2 ≈ 16/3
# Friedmann 8π/3     vs Golden φ          : 8/3/1/2 ≈ 16/3
# Critical density   vs Golden φ          : 3/8/1/2 ≈ 3/4
# Critical density   vs Golden φ          : 3/8/1/2 ≈ 3/4
#
# 🔑  INTEGER RELATION SEARCH (≤5 terms, |c|≤30)…
#   Found: -1·1/4 + 1·1/4 = 0
#   (elapsed 0.01s)

# %%
"""
Physics Constants Relationship Analyzer - Streamlined Version
============================================================

A tool for discovering mathematical relationships between numerical coefficients
in fundamental physics equations.

This is a streamlined version with minimal enhancements to the original code.
Key improvements:
1. Better code organization and comments
2. Enhanced ratio scanning
3. Improved reporting
4. Simple visualization option

Author: Manus AI (based on original code)
Date: May 22, 2025
"""

import sympy as sp
import numpy as np
import math
import itertools
import time
from fractions import Fraction
from collections import defaultdict

# ============================================================
# 1.  Symbols & "unit" symbols to strip
# ============================================================
ℏ, c, G, k_B, α = sp.symbols('hbar c G k_B alpha', positive=True)
ε0, μ0, e, σ_SB, h = sp.symbols('epsilon_0 mu_0 e sigma_SB h', positive=True)
STRIP = {c, ℏ, G, k_B, h, ε0, μ0}

# ============================================================
# 2.  Equation library
# ============================================================
E, m, F, a, q1, q2, r, ν, T = sp.symbols('E m F a q1 q2 r nu T')
λ, ω, η, ρ, Δ = sp.symbols('lambda omega eta rho Delta')
Z0 = sp.symbols('Z_0')

# Dictionary of physics equations with their names as keys
EQU = {
    "Einstein E=mc²":        sp.Eq(E, m*c**2),
    "Newton II":             sp.Eq(F, m*a),
    "Planck E=hν":           sp.Eq(E, h*ν),
    "de Broglie λ":          sp.Eq(λ, ℏ/(m*c)),
    "Compton λ_c":           sp.Eq(λ, ℏ/(m*c)),
    "Coulomb law":           sp.Eq(F, 1/(4*sp.pi*ε0)*q1*q2/r**2),
    "Vacuum impedance":      sp.Eq(Z0, μ0*c),
    "Fine-structure α":      sp.Eq(α, e**2/(4*sp.pi*ε0*ℏ*c)),
    "Bohr radius":           sp.Eq(sp.Symbol('a0'), 4*sp.pi*ε0*ℏ**2/(m*e**2)),
    "Rydberg R∞":            sp.Eq(sp.Symbol('R_inf'), α**2*m*c/(2*h)),
    "Boltzmann kT":          sp.Eq(E, k_B*T),
    "Stefan–Boltzmann":      sp.Eq(σ_SB, sp.pi**2*k_B**4/(60*ℏ**3*c**2)),
    "Black-body u":          sp.Eq(sp.Symbol('u'), 8*sp.pi**5*k_B**4/(15*h**3*c**3)),
    "Casimir P":             sp.Eq(sp.Symbol('P_cas'), -sp.pi**2*ℏ*c/(240*a**4)),
    "BCS gap":               sp.Eq(Δ, 3.528*k_B*T),
    "ζ(3)":                  sp.Eq(sp.Symbol('zeta3'), sp.zeta(3)),
    "Catalan G":             sp.Eq(sp.Symbol('G_cat'), sp.Catalan),
    "Golden φ":              sp.Eq(sp.Symbol('phi'), (1+sp.sqrt(5))/2),
    # Additional equations
    "Gravitational force":   sp.Eq(F, G*m*sp.Symbol('m2')/r**2),
    "Schwarzschild radius":  sp.Eq(sp.Symbol('r_s'), 2*G*m/c**2),
}

# ============================================================
# 3.  Coefficient extraction functions
# ============================================================
def strip_units(expr):
    """Remove physical units (constants in STRIP) from expressions."""
    return sp.factor(expr.xreplace({u:1 for u in STRIP}), sp.pi, sp.E)

def gather_coeffs(eq, label):
    """
    Extract numerical coefficients from an equation.

    Args:
        eq: SymPy equation
        label: Name of the equation

    Returns:
        List of tuples (numerical value, string representation, equation label)
    """
    lst = []
    for side in (eq.lhs, eq.rhs):
        s = strip_units(side)
        for term in sp.Add.make_args(s.expand()):
            coeff, _ = term.as_coeff_Mul()
            if coeff not in (1, -1):
                lst.append((float(coeff.evalf(50)), str(coeff), label))
    return lst

# Extract coefficients from all equations
def extract_all_coeffs():
    """Extract coefficients from all equations in the library."""
    all_coeffs = []
    for name, eq in EQU.items():
        all_coeffs += gather_coeffs(eq, name)
    return all_coeffs

# ============================================================
# 4.  Constant catalogue
# ============================================================
def build_constant_catalogue():
    """Build a dictionary of mathematical constants for comparison."""
    TARGETS = {}

    # Basic constants
    TARGETS["π"] = np.pi
    TARGETS["e"] = np.e
    TARGETS["π²"] = np.pi**2
    TARGETS["√2"] = np.sqrt(2)
    TARGETS["√3"] = np.sqrt(3)

    # Multiples of π
    for n in range(1, 11):
        TARGETS[f"{n}π"] = n*np.pi

    # Fractions of π
    for n in range(1, 11):
        TARGETS[f"π/{n}"] = np.pi/n

    # Reciprocals
    TARGETS.update({f"1/({k})": 1/v for k, v in list(TARGETS.items())})

    return TARGETS

# ============================================================
# 5.  Ratio scanning
# ============================================================
def scan_ratios(all_coeffs, TARGETS, tolerance=1e-6):
    """
    Scan for ratio relationships between coefficients.

    Args:
        all_coeffs: List of coefficient tuples
        TARGETS: Dictionary of mathematical constants
        tolerance: Matching tolerance

    Returns:
        Dictionary of ratio hits
    """
    hits = defaultdict(list)

    for (v1, s1, e1), (v2, s2, e2) in itertools.combinations(all_coeffs, 2):
        if abs(v2) < 1e-50:  # Avoid division by zero or very small numbers
            continue

        r = v1 / v2

        # Check against known constants
        for lbl, val in TARGETS.items():
            # Check both direct and inverse relationships
            if (abs(r - val) < tolerance * abs(val) or
                abs(r - 1/val) < tolerance * abs(val)):
                relation = "≈" if abs(r - val) < tolerance * abs(val) else "≈ 1/"
                hits[(e1, e2)].append(f"{s1}/{s2} {relation} {lbl}")

        # Check for simple rational approximations
        q = Fraction(r).limit_denominator(50)
        if abs(r - float(q)) < tolerance * abs(float(q)):
            if max(abs(q.numerator), q.denominator) > 1:  # Skip trivial fractions
                hits[(e1, e2)].append(f"{s1}/{s2} ≈ {q.numerator}/{q.denominator}")

    return hits

# ============================================================
# 6.  Integer relation search
# ============================================================
def find_integer_relations(all_coeffs, max_terms=6, max_coeff=50, tolerance=1e-10):
    """
    Find integer relations between coefficients.

    Args:
        all_coeffs: List of coefficient tuples
        max_terms: Maximum number of terms in relations
        max_coeff: Maximum coefficient magnitude
        tolerance: Matching tolerance

    Returns:
        List of integer relation strings
    """
    values = [v for v, _, _ in all_coeffs]
    labels = [f"{s} ({e})" for _, s, e in all_coeffs]

    # Find relations
    relation = brute_pslq(values, max_terms, max_coeff, tolerance)

    if relation:
        # Format the relation for display
        terms = []
        for i, coef in enumerate(relation):
            if coef != 0:
                sign = "+" if coef > 0 and i > 0 else ""
                terms.append(f"{sign}{coef}·{labels[i]}")

        return [" ".join(terms) + " = 0"]

    return []

def brute_pslq(vals, max_terms=6, max_coeff=50, tol=1e-10):
    """
    Brute-force search for integer relations.

    Args:
        vals: List of values to check
        max_terms: Maximum number of terms in relations
        max_coeff: Maximum coefficient magnitude
        tol: Tolerance for zero

    Returns:
        List of coefficients or None
    """
    n = len(vals)

    # Try different subset sizes
    for k in range(2, min(max_terms, n) + 1):
        # Generate combinations of indices
        for idx in itertools.combinations(range(n), k):
            subset = [vals[i] for i in idx]

            # Skip if any value is too small
            if any(abs(v) < 1e-50 for v in subset):
                continue

            # Try coefficient combinations
            for coeffs in itertools.product(range(-max_coeff, max_coeff + 1), repeat=k):
                # Skip all zeros
                if all(c == 0 for c in coeffs):
                    continue

                # Skip if not coprime
                if math.gcd(*[abs(c) for c in coeffs if c != 0]) != 1:
                    continue

                # Check if linear combination is close to zero
                if abs(sum(c * v for c, v in zip(coeffs, subset))) < tol:
                    # Construct full relation vector
                    rel = [0] * n
                    for i, c in zip(idx, coeffs):
                        rel[i] = c
                    return rel

    return None

# ============================================================
# 7.  Simple visualization (optional)
# ============================================================
def create_simple_visualization(ratio_hits, filename="relationships.txt"):
    """
    Create a simple text visualization of the relationships.

    Args:
        ratio_hits: Dictionary of ratio hits
        filename: Output filename
    """
    with open(filename, 'w') as f:
        f.write("RELATIONSHIP NETWORK\n")
        f.write("===================\n\n")

        # Count relationships between equations
        equation_connections = defaultdict(int)
        for (e1, e2), hits in ratio_hits.items():
            equation_connections[e1] += len(hits)
            equation_connections[e2] += len(hits)

        # Sort equations by number of connections
        sorted_equations = sorted(equation_connections.items(),
                                 key=lambda x: x[1], reverse=True)

        f.write("Equations by number of relationships:\n")
        f.write("-----------------------------------\n")
        for eq, count in sorted_equations:
            f.write(f"{eq}: {count} relationships\n")

        f.write("\nDetailed relationships:\n")
        f.write("---------------------\n")
        for (e1, e2), hits in sorted(ratio_hits.items()):
            f.write(f"{e1} <-> {e2}:\n")
            for hit in hits:
                f.write(f"  {hit}\n")
            f.write("\n")

# ============================================================
# 8.  Main function
# ============================================================
def analyze_physics_relationships(tolerance=1e-6, max_terms=6, max_coeff=50,
                                 create_viz=True):
    """
    Run the complete analysis pipeline.

    Args:
        tolerance: Tolerance for ratio matching
        max_terms: Maximum terms in integer relations
        max_coeff: Maximum coefficient magnitude
        create_viz: Whether to create visualization

    Returns:
        Tuple of (ratio_hits, integer_relations)
    """
    print("\n" + "="*80)
    print("PHYSICS CONSTANTS RELATIONSHIP ANALYSIS")
    print("="*80 + "\n")

    # Extract coefficients
    print("Extracting coefficients from equations...")
    all_coeffs = extract_all_coeffs()
    print(f"Found {len(all_coeffs)} coefficients from {len(EQU)} equations.\n")

    # Build constant catalogue
    TARGETS = build_constant_catalogue()
    print(f"Built catalogue with {len(TARGETS)} mathematical constants.\n")

    # Scan for ratio relationships
    print("Scanning for ratio relationships...")
    ratio_hits = scan_ratios(all_coeffs, TARGETS, tolerance)
    total_hits = sum(len(hits) for hits in ratio_hits.values())
    print(f"Found {total_hits} ratio relationships between {len(ratio_hits)} equation pairs.\n")

    # Find integer relations
    print("Searching for integer relations...")
    integer_relations = find_integer_relations(all_coeffs, max_terms, max_coeff)
    print(f"Found {len(integer_relations)} integer relations.\n")

    # Print results
    print("\n🔍  RATIO HITS\n" + "-"*60)
    if ratio_hits:
        for (a, b), L in ratio_hits.items():
            for txt in L:
                print(f"{a:22s} vs {b:22s}: {txt}")
    else:
        print("  (none within tolerance)")

    print("\n🔑  INTEGER RELATIONS\n" + "-"*60)
    if integer_relations:
        for relation in integer_relations:
            print("  " + relation)
    else:
        print("  None found within limits.")

    # Create visualization if requested
    if create_viz:
        print("\nCreating visualization...")
        create_simple_visualization(ratio_hits)
        print("Visualization saved to 'relationships.txt'")

    return ratio_hits, integer_relations

# ============================================================
# 9.  Add custom equations (optional)
# ============================================================
def add_custom_equation(name, equation, run_analysis=True):
    """
    Add a custom equation to the library and optionally run analysis.

    Args:
        name: Name of the equation
        equation: SymPy equation
        run_analysis: Whether to run analysis after adding

    Example:
        E, m = sp.symbols('E m')
        c = sp.symbols('c', positive=True)
        add_custom_equation("Custom E=mc²", sp.Eq(E, 2*m*c**2))
    """
    EQU[name] = equation
    print(f"Added equation: {name}")

    if run_analysis:
        analyze_physics_relationships()

# ============================================================
# Run the analysis if executed directly
# ============================================================
if __name__ == "__main__":
    analyze_physics_relationships(create_viz=True)
# Out:
# ================================================================================
# PHYSICS CONSTANTS RELATIONSHIP ANALYSIS
# ================================================================================
#
# Extracting coefficients from equations...
# Found 11 coefficients from 20 equations.
#
# Built catalogue with 50 mathematical constants.
#
# Scanning for ratio relationships...
# Found 37 ratio relationships between 31 equation pairs.
#
# Searching for integer relations...
# Found 1 integer relations.
#
#
# 🔍  RATIO HITS
# ------------------------------------------------------------
# Coulomb law            vs Bohr radius           : 1/4/4 ≈ 1/16
# Coulomb law            vs Rydberg R∞            : 1/4/1/2 ≈ 1/2
# Coulomb law            vs Stefan–Boltzmann      : 1/4/1/60 ≈ 15/1
# Coulomb law            vs Black-body u          : 1/4/8/15 ≈ 15/32
# Coulomb law            vs Casimir P             : 1/4/-1/240 ≈ -60/1
# Coulomb law            vs Golden φ              : 1/4/1/2 ≈ 1/2
# Coulomb law            vs Golden φ              : 1/4/1/2 ≈ 1/2
# Coulomb law            vs Schwarzschild radius  : 1/4/2 ≈ 1/8
# Fine-structure α       vs Bohr radius           : 1/4/4 ≈ 1/16
# Fine-structure α       vs Rydberg R∞            : 1/4/1/2 ≈ 1/2
# Fine-structure α       vs Stefan–Boltzmann      : 1/4/1/60 ≈ 15/1
# Fine-structure α       vs Black-body u          : 1/4/8/15 ≈ 15/32
# Fine-structure α       vs Casimir P             : 1/4/-1/240 ≈ -60/1
# Fine-structure α       vs Golden φ              : 1/4/1/2 ≈ 1/2
# Fine-structure α       vs Golden φ              : 1/4/1/2 ≈ 1/2
# Fine-structure α       vs Schwarzschild radius  : 1/4/2 ≈ 1/8
# Bohr radius            vs Rydberg R∞            : 4/1/2 ≈ 8/1
# Bohr radius            vs Stefan–Boltzmann      : 4/1/60 ≈ 240/1
# Bohr radius            vs Black-body u          : 4/8/15 ≈ 15/2
# Bohr radius            vs Casimir P             : 4/-1/240 ≈ -960/1
# Bohr radius            vs Golden φ              : 4/1/2 ≈ 8/1
# Bohr radius            vs Golden φ              : 4/1/2 ≈ 8/1
# Bohr radius            vs Schwarzschild radius  : 4/2 ≈ 2/1
# Rydberg R∞             vs Stefan–Boltzmann      : 1/2/1/60 ≈ 30/1
# Rydberg R∞             vs Black-body u          : 1/2/8/15 ≈ 15/16
# Rydberg R∞             vs Casimir P             : 1/2/-1/240 ≈ -120/1
# Rydberg R∞             vs Schwarzschild radius  : 1/2/2 ≈ 1/4
# Stefan–Boltzmann       vs Black-body u          : 1/60/8/15 ≈ 1/32
# Stefan–Boltzmann       vs Casimir P             : 1/60/-1/240 ≈ -4/1
# Stefan–Boltzmann       vs Golden φ              : 1/60/1/2 ≈ 1/30
# Stefan–Boltzmann       vs Golden φ              : 1/60/1/2 ≈ 1/30
# Black-body u           vs Casimir P             : 8/15/-1/240 ≈ -128/1
# Black-body u           vs Golden φ              : 8/15/1/2 ≈ 16/15
# Black-body u           vs Golden φ              : 8/15/1/2 ≈ 16/15
# Black-body u           vs Schwarzschild radius  : 8/15/2 ≈ 4/15
# Golden φ               vs Schwarzschild radius  : 1/2/2 ≈ 1/4
# Golden φ               vs Schwarzschild radius  : 1/2/2 ≈ 1/4
#
# 🔑  INTEGER RELATIONS
# ------------------------------------------------------------
#   -1·1/4 (Coulomb law) +1·1/4 (Fine-structure α) = 0
#
# Creating visualization...
# Visualization saved to 'relationships.txt'
