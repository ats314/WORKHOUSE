# %%
import math

def mass(n, Y):
    λ = 0.732    # Corrected from rigorous optimization
    ω = 3.883    # ≈2π/φ (golden ratio)
    φ = -0.871
    ε = 0.123
    K = 0.0859

    angle = ω*n + φ + Y*(math.pi/3)
    log_m = λ*n + ε*math.sin(angle) + math.log10(K * 2**Y)
    return 10**log_m
