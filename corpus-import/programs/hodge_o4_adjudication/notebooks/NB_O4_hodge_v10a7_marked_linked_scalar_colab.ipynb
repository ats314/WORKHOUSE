# %% [markdown]
# # HODGE v10a.7 — Marked Linked O(u^4) Scalar Ledger
#
# Self-contained Colab production run for the remaining SU(3) fourth-order rest scalar.
#
# Default mode:
# - L=5 clean isolation volume
# - one exact cubic representative polarization for the expensive support-resolved scalar run
# - uses the already-certified v10a.6 exact Q1 fold values
# - cold-computes the new direct Gamma scalar \(D_A\)
# - cold-computes one-face and adjacent-pair vacuum linked weights
# - checks the lower-order \(m_2,m_3\) linked subtraction before unblinding \(m_4^{rest}\)
# - historical \(m_4\) is never loaded
#
# For redundant full-T1 checking, set `V10A7_SUPPORT_POLS="0,1,2"`.
# For the additional protected mobility reconstruction, set `V10A7_DO_SHAPE="1"`.

# %%
# HODGE v10a.7 — single-cell Colab launcher
import os, base64, gzip

os.environ.setdefault("PREFER_GPU", "1")
os.environ.setdefault("GLUE_L", "5")
os.environ.setdefault("V10A7_PROGRESS", "1")
os.environ.setdefault("V10A7_SUPPORT_POLS", "2")
os.environ.setdefault("V10A7_RECHECK_Q1", "0")
os.environ.setdefault("V10A7_DO_SHAPE", "0")
os.environ.setdefault("V10A7_UNBLIND", "1")

_payload = '...'
_code = gzip.decompress(base64.b64decode(_payload)).decode("utf-8")
print("Launching HODGE v10a.7 marked linked O(u^4) scalar ledger...")
exec(compile(_code, "ENGINE_O4_hodge_v10a7_marked_linked_scalar.py", "exec"))
